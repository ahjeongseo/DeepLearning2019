# %% [markdown]
# # M2177.003100 Deep Learning <br>Assignment #5 Part 1: Implementing and Training a Deep Q-Network

# %% [markdown]
# Copyright (C) Data Science Laboratory, Seoul National University. This material is for educational uses only. Some contents are based on the material provided by other paper/book authors and may be copyrighted by them. Written by Hyungyu Lee, November 2019

# %% [markdown]
# In this notebook, you will implement one of famous reinforcement learning algorithm, Deep Q-Network (DQN) of DeepMind. <br>
# The goal here is to understand a basic form of DQN [1, 2] and learn how to use OpenAI Gym toolkit [3].<br>
# You need to follow the instructions to implement the given classes.
#
# 1. [Play](#play) ( 50 points )
#
# **Note**: certain details are missing or ambiguous on purpose, in order to test your knowledge on the related materials. However, if you really feel that something essential is missing and cannot proceed to the next step, then contact the teaching staff with clear description of your problem.
#
# ### Submitting your work:
# <font color=red>**DO NOT clear the final outputs**</font> so that TAs can grade both your code and results.
# Once you have done **two parts of the assignment**, run the *CollectSubmission.sh* script with your **Team number** as input argument. <br>
# This will produce a zipped file called *[Your team number].tar.gz*. Please submit this file on ETL. &nbsp;&nbsp; (Usage: ./*CollectSubmission.sh* &nbsp; Team_#)
#
# ### Some helpful references for assignment #4 :
# - [1] Mnih, Volodymyr, et al. "Playing atari with deep reinforcement learning." arXiv preprint arXiv:1312.5602 (2013). [[pdf]](https://www.google.co.kr/url?sa=t&rct=j&q=&esrc=s&source=web&cd=3&cad=rja&uact=8&ved=0ahUKEwiI3aqPjavVAhXBkJQKHZsIDpgQFgg7MAI&url=https%3A%2F%2Fwww.cs.toronto.edu%2F~vmnih%2Fdocs%2Fdqn.pdf&usg=AFQjCNEd1AJoM72DeDpI_GBoPuv7NnVoFA)
# - [2] Mnih, Volodymyr, et al. "Human-level control through deep reinforcement learning." Nature 518.7540 (2015): 529-533. [[pdf]](https://www.nature.com/nature/journal/v518/n7540/pdf/nature14236.pdf)
# - [3] OpenAI GYM website [[link]](https://gym.openai.com/envs) and [[git]](https://github.com/openai/gym)

# %% [markdown]
# ## 0. OpenAI Gym
#
# OpenAI Gym is a toolkit to support diverse environments for developing reinforcement learning algorithms. You can use the toolkit with Python as well as TensorFlow. Installation guide of OpenAI Gym is offered by [this link](https://github.com/openai/gym#installation) or just type the command "pip install gym" (as well as "pip install gym[atari]" for Part2).
#
# After you set up OpenAI Gym, you can use APIs of the toolkit by inserting <font color=red>import gym</font> into your code. In this assignment, you must build one of famous reinforcement learning algorithms whose agent can run on OpenAI Gym environments. Please check how to use APIs such as funcions interacting with environments in the followings.

# %%
import tensorflow as tf
import cv2 
import gym
import numpy as np
import os
import argparse
import sys
from collections import deque
import random

#os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
#os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# Make an environment instance of CartPole-v0.
env = gym.make('CartPole-v0')

# Before interacting with the environment and starting a new episode, you must reset the environment's state.
state = env.reset()

#rendering game screens, do not need for assignment evaluation
env.render() 

# You can check action space and state (observation) space.
num_actions = env.action_space.n
state_shape = env.observation_space.shape
print(num_actions)
print(state_shape)

# "step" function performs agent's actions given current state of the environment and returns several values.
# Input: action (numerical data)
#        - env.action_space.sample(): select a random action among possible actions.
# Output: next_state (numerical data, next state of the environment after performing given action)
#         reward (numerical data, reward of given action given current state)
#         terminal (boolean data, True means the agent is done in the environment)
next_state, reward, terminal, info = env.step(env.action_space.sample())
# Out:
# [2019-12-08 16:34:25,310] Making new env: CartPole-v0
# /home/kddlab/anaconda3/envs/deep-learning-19/lib/python3.6/site-packages/gym/envs/registration.py:17: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# 2
# (4,)

# %% [markdown]
# ## 1. Implement a DQN agent
# ## 1) Overview of implementation in the notebook
#
# The assignment is based on a method named by Deep Q-Network (DQN) [1,2]. You could find the details of DQN in the papers. The followings show briefly architecture of DQN and its training computation flow.
#
# - (Pink flow) Play an episode and save transition records of the episode into a replay memory.
# - (Green flow) Train DQN so that a loss function in the figure is minimized. The loss function is computed using main Q-network and Target Q-network. Target Q-network needs to be periodically updated by copying the main Q-network.
# - (Purple flow) Gradient can be autonomously computed by tensorflow engine, if you build a proper optimizer.
#
# ![](image/architecture.png)
#
# There are major 4 components, each of which needs to be implemented in this notebook. The Agent class must have an instance(s) of each class (Environment, DQN, ReplayMemory).
# - Environment
# - DQN
# - ReplayMemory
# - Agent
#
# ![](image/components.png)

# %% [markdown]
# ## 2) Design classes
#
# In the code cells, there are only names of functions which are used in TA's implementation and their brief explanations. <font color='green'>...</font> means that the functions need more arguments and <font color='green'>pass</font> means that you need to write more codes. The functions may be helpful when you do not know how to start the assignment. Of course, you could change the functions such as deleting/adding functions or extending/reducing roles of the classes, <font color='red'> just keeping the existence of the classes</font>.
#
# ### Environment class

# %%
class Environment(object):
    def __init__(self, args):
        self.env = env
    
    def random_action(self):
        # Return a random action.
        return self.env.action_space.sample()
        
    
    def render_worker(self):
        # If display in your option is true, do rendering. Otherwise, do not.
        # you do not need to render in this assignment
        self.env.render()
    
    def new_episode(self):
        # Start a new episode and return the first state of the new episode.
        return self.env.reset()
    
    def act(self, action):
        # Perform an action which is given by input argument and return the results of acting.
        return self.env.step(action)

# %% [markdown]
# ### ReplayMemory class

# %%
class ReplayMemory(object):
    def __init__(self, args):
        self.capacity = args.memory_size
        self.batch_size = args.batch_size
        self.memory = deque()
    
    def add(self, current_state, action, reward, next_state, terminal):
        # Add current_state, action, reward, terminal to replay_memory (next_state which can be added by your choice). 
        self.memory.append((current_state, action, reward, next_state, terminal))
        if len(self.memory) > self.capacity:
            self.memory.popleft()
    
    def mini_batch(self):
        # Return a mini_batch from replay_memory according to your sampling method. (such as uniform-random sampling in DQN papers)
        return random.sample(self.memory, self.batch_size)

# %% [markdown]
# ### DQN class

# %%
class DQN(object):
    def __init__(self, args, sess, name):
        self.sess = sess
        self.lr = args.learning_rate
        self.input_size = args.input_size[0]
        self.output_size = args.output_size
        self.build_network(name)
        self.loss, self.opt = self.build_optimizer(name)
    
    def build_network(self, name):
        # Make your a deep neural network
        with tf.variable_scope(name, reuse=tf.AUTO_REUSE):
            self.inputs = tf.placeholder(tf.float32,shape=(None, self.input_size))
            layer1 = tf.layers.dense(self.inputs, 10, activation=tf.nn.relu,kernel_initializer=tf.contrib.layers.xavier_initializer())
            layer2 = tf.layers.dense(layer1, 20, activation=tf.nn.relu, kernel_initializer=tf.contrib.layers.xavier_initializer())
            self.pred = tf.layers.dense(layer2, self.output_size)
        
    
    def build_optimizer(self,name):
        # Make your optimizer
        with tf.variable_scope(name, reuse=tf.AUTO_REUSE):
            self.outputs = tf.placeholder(tf.float32,[None,self.output_size])
            self.loss = tf.reduce_mean(tf.square(self.outputs-self.pred))
            self.opt = tf.train.AdamOptimizer(self.lr).minimize(self.loss)
        return self.loss, self.opt
    
    def train_network(self,X,Y):
        # Train the prediction_Q network using a mini-batch sampled from the replay memory
        return self.sess.run([self.loss, self.opt], feed_dict={self.inputs:X, self.outputs:Y})
    
    def update_target_network(self):
        copy_op = []
        pred_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='pred')
        target_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='target')
        for pred_var, target_var in zip(pred_vars, target_vars):
            copy_op.append(target_var.assign(pred_var.value()))
        self.sess.run(copy_op)
    
    def predict_Q(self, state):
        x = np.reshape(state, [-1,self.input_size])
        return self.sess.run(self.pred, feed_dict={self.inputs:x})

# %% [markdown]
# ### Agent class

# %%
class Agent(object):
    def __init__(self, args, sess):
        self.max_episodes = args.max_episodes
        self.train_interval = args.train_interval
        self.sess = sess
        self.discount_factor = 0.99
        self.epsilon = 1.0 
        self.env = Environment(args)
        self.memory = ReplayMemory(args)
        self.input_size = args.input_size
        self.output_size = args.output_size
        self.dqn = DQN(args, self.sess, 'pred')
        self.target_dqn = DQN(args, self.sess, 'target')
        tf.global_variables_initializer().run()
        self.dqn.update_target_network()
        self.saver = tf.train.Saver()
    
    def select_action(self,state):
        # Select an action according ε-greedy. You need to use a random-number generating function and add a library if necessary.
        if np.random.rand(1) <= self.epsilon:
            return self.env.random_action()
        else:
            return np.argmax(self.dqn.predict_Q(state))
    
    def train(self):
        # Train your agent 
        # Several hyper-parameters are determined by your choice
        # Keep epsilon-greedy action selection in your mind 
        for episode in range(self.max_episodes):
            self.epsilon = 1./((episode/3) + 1)
            terminal = False
            count = 0
            state = self.env.new_episode()
            
            while not terminal:
                action = self.select_action(state)
                next_state, reward, terminal, _ = self.env.act(action)
                if terminal:
                    reward = -100
                self.memory.add(state, action, reward, next_state, terminal)
                state = next_state
                count += 1
                if count > 10000:
                    break
            
            print("Episode: {} count: {}".format(episode, count))
            
            if count > 10000:
                pass
            
            if episode % self.train_interval ==1:
                for _ in range(5):
                    batch = self.memory.mini_batch()
                    X = np.empty(0).reshape(0,self.input_size[0])
                    Y = np.empty(0).reshape(0,self.output_size)
                    for state, action, reward, next_state, terminal in batch:
                        Q = self.dqn.predict_Q(state)
                        if terminal:
                            Q[0,action] = reward
                        else:
                            Q[0,action] = reward + self.discount_factor*np.max(self.dqn.predict_Q(next_state))
                        Y = np.vstack([Y,Q])
                        X = np.vstack([X,state])
                    loss, _ = self.dqn.train_network(X,Y)
                print("Loss: ", loss)
                self.dqn.update_target_network()
    
    def play(self):
        # Test your agent 
        # When performing test, you can show the environment's screen by rendering if you want
        state = self.env.new_episode()
        total_reward = 0
        while True:
            self.env.render_worker()
            action= np.argmax(self.dqn.predict_Q(state))
            state, reward, terminal, _ = self.env.act(action)
            total_reward += reward
            if terminal:
                print("Total reward: {}".format(total_reward))
                return total_reward
    
    def save(self):
        checkpoint_dir = 'cartpole'
        if not os.path.exists(checkpoint_dir):
            os.mkdir(checkpoint_dir)
        self.saver.save(self.sess, os.path.join(checkpoint_dir, 'trained_agent'))
        
    def load(self):
        checkpoint_dir = 'cartpole'
        self.saver.restore(self.sess, os.path.join(checkpoint_dir, 'trained_agent'))

# %% [markdown]
# ## 2. Train your agent
#
# Now, you train an agent to play CartPole-v0. Options class is the collection of hyper-parameters that you can choice. Usage of Options class is not mandatory.<br>
# The maximum value of total reward which can be aquired from one episode is 200.
# <font color='red'>**You should show learning status such as the number of observed states and mean/max/min of rewards frequently (for instance, every 100 states).**</font>

# %%
parser = argparse.ArgumentParser(description="CartPole")
parser.add_argument('--env-name', default='CartPole-v0', type=str,
                    help="Environment")
"""
You can add more arguments.
for example, visualize, memory_size, batch_size, discount_factor, eps_max, eps_min, learning_rate, train_interval, copy_interval and so on
"""
parser.add_argument('--input_size', type=int, default=state_shape)
parser.add_argument('--output_size', type=int, default=num_actions)
parser.add_argument('--memory_size', type=int, default=5000)
parser.add_argument('--batch_size', type=int, default=10)
parser.add_argument('--discount_factor', type=float, default=0.9)
parser.add_argument('--learning_rate', type=float, default=1e-1)
parser.add_argument('--train_interval', type=int, default=10)
parser.add_argument('--max_episodes', type=int, default=1200)
sys.argv = ['-f']

config = tf.ConfigProto()
# If you use a GPU, uncomment
#os.environ["CUDA_VISIBLE_DEVICES"] = '0'
config.log_device_placement = False
config.gpu_options.allow_growth = True
with tf.Session(config=config) as sess:
    args = parser.parse_args()
    myAgent = Agent(args, sess) # It depends on your class implementation
    myAgent.train()
    myAgent.save()
# Out:
# Episode: 0 count: 15
# Episode: 1 count: 20
# Loss:  2.426657
# Episode: 2 count: 27
# Episode: 3 count: 27
# Episode: 4 count: 30
# Episode: 5 count: 18
# Episode: 6 count: 30
# Episode: 7 count: 30
# Episode: 8 count: 20
# Episode: 9 count: 24
# Episode: 10 count: 27
# Episode: 11 count: 24
# Loss:  516.10046
# Episode: 12 count: 12
# Episode: 13 count: 9
# Episode: 14 count: 14
# Episode: 15 count: 10
# Episode: 16 count: 11
# Episode: 17 count: 10
# Episode: 18 count: 9
# Episode: 19 count: 11
# Episode: 20 count: 10
# Episode: 21 count: 10
# Loss:  1.4268222
# Episode: 22 count: 8
# Episode: 23 count: 11
# Episode: 24 count: 10
# Episode: 25 count: 10
# Episode: 26 count: 8
# Episode: 27 count: 10
# Episode: 28 count: 10
# Episode: 29 count: 9
# Episode: 30 count: 11
# Episode: 31 count: 12
# Loss:  521.22845
# Episode: 32 count: 9
# Episode: 33 count: 12
# Episode: 34 count: 10
# Episode: 35 count: 10
# Episode: 36 count: 9
# Episode: 37 count: 9
# Episode: 38 count: 10
# Episode: 39 count: 9
# Episode: 40 count: 10
# Episode: 41 count: 10
# Loss:  494.77936
# Episode: 42 count: 12
# Episode: 43 count: 10
# Episode: 44 count: 12
# Episode: 45 count: 11
# Episode: 46 count: 11
# Episode: 47 count: 13
# Episode: 48 count: 12
# Episode: 49 count: 12
# Episode: 50 count: 16
# Episode: 51 count: 11
# Loss:  0.95585614
# Episode: 52 count: 15
# Episode: 53 count: 18
# Episode: 54 count: 17
# Episode: 55 count: 12
# Episode: 56 count: 19
# Episode: 57 count: 14
# Episode: 58 count: 19
# Episode: 59 count: 18
# Episode: 60 count: 15
# Episode: 61 count: 13
# Loss:  490.48145
# Episode: 62 count: 37
# Episode: 63 count: 84
# Episode: 64 count: 22
# Episode: 65 count: 27
# Episode: 66 count: 27
# Episode: 67 count: 31
# Episode: 68 count: 58
# Episode: 69 count: 57
# Episode: 70 count: 31
# Episode: 71 count: 38
# Loss:  0.8020875
# Episode: 72 count: 33
# Episode: 73 count: 33
# Episode: 74 count: 30
# Episode: 75 count: 29
# Episode: 76 count: 23
# Episode: 77 count: 27
# Episode: 78 count: 21
# Episode: 79 count: 53
# Episode: 80 count: 32
# Episode: 81 count: 37
# Loss:  0.64222586
# Episode: 82 count: 32
# Episode: 83 count: 23
# Episode: 84 count: 80
# Episode: 85 count: 41
# Episode: 86 count: 43
# Episode: 87 count: 62
# Episode: 88 count: 47
# Episode: 89 count: 52
# Episode: 90 count: 63
# Episode: 91 count: 59
# Loss:  0.8748352
# Episode: 92 count: 79
# Episode: 93 count: 40
# Episode: 94 count: 135
# Episode: 95 count: 26
# Episode: 96 count: 107
# Episode: 97 count: 33
# Episode: 98 count: 27
# Episode: 99 count: 33
# Episode: 100 count: 92
# Episode: 101 count: 31
# Loss:  0.5558866
# Episode: 102 count: 46
# Episode: 103 count: 37
# Episode: 104 count: 99
# Episode: 105 count: 31
# Episode: 106 count: 48
# Episode: 107 count: 36
# Episode: 108 count: 29
# Episode: 109 count: 39
# Episode: 110 count: 63
# Episode: 111 count: 25
# Loss:  926.4059
# Episode: 112 count: 56
# Episode: 113 count: 35
# Episode: 114 count: 27
# Episode: 115 count: 117
# Episode: 116 count: 27
# Episode: 117 count: 24
# Episode: 118 count: 32
# Episode: 119 count: 31
# Episode: 120 count: 40
# Episode: 121 count: 27
# Loss:  1.0386269
# Episode: 122 count: 17
# Episode: 123 count: 20
# Episode: 124 count: 12
# Episode: 125 count: 13
# Episode: 126 count: 19
# Episode: 127 count: 13
# Episode: 128 count: 15
# Episode: 129 count: 15
# Episode: 130 count: 18
# Episode: 131 count: 18
# Loss:  0.76673687
# Episode: 132 count: 13
# Episode: 133 count: 10
# Episode: 134 count: 10
# Episode: 135 count: 13
# Episode: 136 count: 13
# Episode: 137 count: 11
# Episode: 138 count: 12
# Episode: 139 count: 13
# Episode: 140 count: 11
# Episode: 141 count: 13
# Loss:  1.2545184
# Episode: 142 count: 10
# Episode: 143 count: 10
# Episode: 144 count: 10
# Episode: 145 count: 9
# Episode: 146 count: 9
# Episode: 147 count: 9
# Episode: 148 count: 9
# Episode: 149 count: 8
# Episode: 150 count: 9
# Episode: 151 count: 9
# Loss:  469.32892
# Episode: 152 count: 11
# Episode: 153 count: 10
# Episode: 154 count: 9
# Episode: 155 count: 10
# Episode: 156 count: 9
# Episode: 157 count: 9
# Episode: 158 count: 9
# Episode: 159 count: 10
# Episode: 160 count: 10
# Episode: 161 count: 9
# Loss:  456.3037
# Episode: 162 count: 34
# Episode: 163 count: 29
# Episode: 164 count: 21
# Episode: 165 count: 27
# Episode: 166 count: 22
# Episode: 167 count: 33
# Episode: 168 count: 23
# Episode: 169 count: 33
# Episode: 170 count: 29
# Episode: 171 count: 32
# Loss:  389.12497
# Episode: 172 count: 9
# Episode: 173 count: 9
# Episode: 174 count: 9
# Episode: 175 count: 9
# Episode: 176 count: 9
# Episode: 177 count: 9
# Episode: 178 count: 10
# Episode: 179 count: 9
# Episode: 180 count: 10
# Episode: 181 count: 10
# Loss:  339.28925
# Episode: 182 count: 8
# Episode: 183 count: 9
# Episode: 184 count: 11
# Episode: 185 count: 9
# Episode: 186 count: 9
# Episode: 187 count: 10
# Episode: 188 count: 10
# Episode: 189 count: 9
# Episode: 190 count: 9
# Episode: 191 count: 9
# Loss:  414.71857
# Episode: 192 count: 9
# Episode: 193 count: 9
# Episode: 194 count: 10
# Episode: 195 count: 10
# Episode: 196 count: 9
# Episode: 197 count: 9
# Episode: 198 count: 9
# Episode: 199 count: 10
# Episode: 200 count: 11
# Episode: 201 count: 10
# Loss:  128.72958
# Episode: 202 count: 9
# Episode: 203 count: 9
# Episode: 204 count: 10
# Episode: 205 count: 10
# Episode: 206 count: 8
# Episode: 207 count: 8
# Episode: 208 count: 9
# Episode: 209 count: 10
# Episode: 210 count: 9
# Episode: 211 count: 9
# Loss:  13.841417
# Episode: 212 count: 16
# Episode: 213 count: 29
# Episode: 214 count: 16
# Episode: 215 count: 18
# Episode: 216 count: 20
# Episode: 217 count: 15
# Episode: 218 count: 17
# Episode: 219 count: 20
# Episode: 220 count: 14
# Episode: 221 count: 27
# Loss:  8.068026
# Episode: 222 count: 10
# Episode: 223 count: 9
# Episode: 224 count: 10
# Episode: 225 count: 9
# Episode: 226 count: 10
# Episode: 227 count: 10
# Episode: 228 count: 9
# Episode: 229 count: 9
# Episode: 230 count: 9
# Episode: 231 count: 10
# Loss:  10.438291
# Episode: 232 count: 11
# Episode: 233 count: 8
# Episode: 234 count: 9
# Episode: 235 count: 11
# Episode: 236 count: 9
# Episode: 237 count: 10
# Episode: 238 count: 10
# Episode: 239 count: 8
# Episode: 240 count: 10
# Episode: 241 count: 9
# Loss:  12.5701275
# Episode: 242 count: 11
# Episode: 243 count: 10
# Episode: 244 count: 8
# Episode: 245 count: 10
# Episode: 246 count: 10
# Episode: 247 count: 10
# Episode: 248 count: 9
# Episode: 249 count: 9
# Episode: 250 count: 9
# Episode: 251 count: 9
# Loss:  40.796963
# Episode: 252 count: 9
# Episode: 253 count: 10
# Episode: 254 count: 10
# Episode: 255 count: 9
# Episode: 256 count: 10
# Episode: 257 count: 10
# Episode: 258 count: 11
# Episode: 259 count: 9
# Episode: 260 count: 8
# Episode: 261 count: 9
# Loss:  386.95834
# Episode: 262 count: 10
# Episode: 263 count: 8
# Episode: 264 count: 9
# Episode: 265 count: 9
# Episode: 266 count: 9
# Episode: 267 count: 9
# Episode: 268 count: 10
# Episode: 269 count: 10
# Episode: 270 count: 9
# Episode: 271 count: 9
# Loss:  4.169092
# Episode: 272 count: 23
# Episode: 273 count: 32
# Episode: 274 count: 22
# Episode: 275 count: 26
# Episode: 276 count: 26
# Episode: 277 count: 39
# Episode: 278 count: 26
# Episode: 279 count: 26
# Episode: 280 count: 36
# Episode: 281 count: 31
# Loss:  2.9456449
# Episode: 282 count: 41
# Episode: 283 count: 65
# Episode: 284 count: 61
# Episode: 285 count: 47
# Episode: 286 count: 33
# Episode: 287 count: 88
# Episode: 288 count: 47
# Episode: 289 count: 58
# Episode: 290 count: 53
# Episode: 291 count: 64
# Loss:  2.2287657
# Episode: 292 count: 9
# Episode: 293 count: 10
# Episode: 294 count: 9
# Episode: 295 count: 9
# Episode: 296 count: 12
# Episode: 297 count: 10
# Episode: 298 count: 10
# Episode: 299 count: 8
# Episode: 300 count: 10
# Episode: 301 count: 10
# Loss:  6.1328387
# Episode: 302 count: 9
# Episode: 303 count: 10
# Episode: 304 count: 9
# Episode: 305 count: 9
# Episode: 306 count: 10
# Episode: 307 count: 10
# Episode: 308 count: 10
# Episode: 309 count: 10
# Episode: 310 count: 8
# Episode: 311 count: 9
# Loss:  1.4861577
# Episode: 312 count: 9
# Episode: 313 count: 11
# Episode: 314 count: 10
# Episode: 315 count: 10
# Episode: 316 count: 9
# Episode: 317 count: 9
# Episode: 318 count: 9
# Episode: 319 count: 10
# Episode: 320 count: 11
# Episode: 321 count: 8
# Loss:  11.151811
# Episode: 322 count: 17
# Episode: 323 count: 14
# Episode: 324 count: 13
# Episode: 325 count: 14
# Episode: 326 count: 15
# Episode: 327 count: 14
# Episode: 328 count: 14
# Episode: 329 count: 12
# Episode: 330 count: 15
# Episode: 331 count: 15
# Loss:  410.25845
# Episode: 332 count: 9
# Episode: 333 count: 8
# Episode: 334 count: 10
# Episode: 335 count: 10
# Episode: 336 count: 8
# Episode: 337 count: 10
# Episode: 338 count: 8
# Episode: 339 count: 10
# Episode: 340 count: 10
# Episode: 341 count: 9
# Loss:  370.5229
# Episode: 342 count: 10
# Episode: 343 count: 9
# Episode: 344 count: 9
# Episode: 345 count: 9
# Episode: 346 count: 10
# Episode: 347 count: 9
# Episode: 348 count: 10
# Episode: 349 count: 10
# Episode: 350 count: 9
# Episode: 351 count: 9
# Loss:  12.508669
# Episode: 352 count: 10
# Episode: 353 count: 10
# Episode: 354 count: 9
# Episode: 355 count: 9
# Episode: 356 count: 9
# Episode: 357 count: 9
# Episode: 358 count: 10
# Episode: 359 count: 11
# Episode: 360 count: 10
# Episode: 361 count: 10
# Loss:  221.09761
# Episode: 362 count: 9
# Episode: 363 count: 8
# Episode: 364 count: 8
# Episode: 365 count: 9
# Episode: 366 count: 10
# Episode: 367 count: 10
# Episode: 368 count: 8
# Episode: 369 count: 10
# Episode: 370 count: 9
# Episode: 371 count: 10
# Loss:  115.46681
# Episode: 372 count: 9
# Episode: 373 count: 9
# Episode: 374 count: 10
# Episode: 375 count: 10
# Episode: 376 count: 8
# Episode: 377 count: 10
# Episode: 378 count: 10
# Episode: 379 count: 10
# Episode: 380 count: 10
# Episode: 381 count: 10
# Loss:  15.208049
# Episode: 382 count: 9
# Episode: 383 count: 11
# Episode: 384 count: 10
# Episode: 385 count: 8
# Episode: 386 count: 9
# Episode: 387 count: 10
# Episode: 388 count: 10
# Episode: 389 count: 10
# Episode: 390 count: 8
# Episode: 391 count: 10
# Loss:  51.90572
# Episode: 392 count: 10
# Episode: 393 count: 10
# Episode: 394 count: 10
# Episode: 395 count: 10
# Episode: 396 count: 10
# Episode: 397 count: 10
# Episode: 398 count: 9
# Episode: 399 count: 10
# Episode: 400 count: 10
# Episode: 401 count: 11
# Loss:  8.404746
# Episode: 402 count: 17
# Episode: 403 count: 15
# Episode: 404 count: 18
# Episode: 405 count: 14
# Episode: 406 count: 14
# Episode: 407 count: 12
# Episode: 408 count: 15
# Episode: 409 count: 13
# Episode: 410 count: 13
# Episode: 411 count: 15
# Loss:  218.67717
# Episode: 412 count: 23
# Episode: 413 count: 20
# Episode: 414 count: 18
# Episode: 415 count: 18
# Episode: 416 count: 16
# Episode: 417 count: 19
# Episode: 418 count: 22
# Episode: 419 count: 21
# Episode: 420 count: 18
# Episode: 421 count: 23
# Loss:  57.99645
# Episode: 422 count: 14
# Episode: 423 count: 20
# Episode: 424 count: 16
# Episode: 425 count: 16
# Episode: 426 count: 21
# Episode: 427 count: 21
# Episode: 428 count: 18
# Episode: 429 count: 22
# Episode: 430 count: 16
# Episode: 431 count: 16
# Loss:  214.37798
# Episode: 432 count: 20
# Episode: 433 count: 15
# Episode: 434 count: 18
# Episode: 435 count: 15
# Episode: 436 count: 15
# Episode: 437 count: 15
# Episode: 438 count: 16
# Episode: 439 count: 23
# Episode: 440 count: 14
# Episode: 441 count: 16
# Loss:  59.46041
# Episode: 442 count: 34
# Episode: 443 count: 21
# Episode: 444 count: 28
# Episode: 445 count: 20
# Episode: 446 count: 23
# Episode: 447 count: 18
# Episode: 448 count: 18
# Episode: 449 count: 22
# Episode: 450 count: 25
# Episode: 451 count: 20
# Loss:  54.192608
# Episode: 452 count: 173
# Episode: 453 count: 28
# Episode: 454 count: 34
# Episode: 455 count: 38
# Episode: 456 count: 38
# Episode: 457 count: 200
# Episode: 458 count: 34
# Episode: 459 count: 52
# Episode: 460 count: 36
# Episode: 461 count: 34
# Loss:  55.038963
# Episode: 462 count: 63
# Episode: 463 count: 48
# Episode: 464 count: 65
# Episode: 465 count: 44
# Episode: 466 count: 39
# Episode: 467 count: 32
# Episode: 468 count: 64
# Episode: 469 count: 40
# Episode: 470 count: 29
# Episode: 471 count: 38
# Loss:  4.509649
# Episode: 472 count: 20
# Episode: 473 count: 23
# Episode: 474 count: 30
# Episode: 475 count: 31
# Episode: 476 count: 26
# Episode: 477 count: 22
# Episode: 478 count: 27
# Episode: 479 count: 25
# Episode: 480 count: 20
# Episode: 481 count: 28
# Loss:  31.277843
# Episode: 482 count: 11
# Episode: 483 count: 11
# Episode: 484 count: 9
# Episode: 485 count: 9
# Episode: 486 count: 11
# Episode: 487 count: 9
# Episode: 488 count: 9
# Episode: 489 count: 8
# Episode: 490 count: 9
# Episode: 491 count: 11
# Loss:  11.43545
# Episode: 492 count: 10
# Episode: 493 count: 8
# Episode: 494 count: 9
# Episode: 495 count: 9
# Episode: 496 count: 9
# Episode: 497 count: 10
# Episode: 498 count: 11
# Episode: 499 count: 10
# Episode: 500 count: 10
# Episode: 501 count: 10
# Loss:  309.60974
# Episode: 502 count: 9
# Episode: 503 count: 9
# Episode: 504 count: 10
# Episode: 505 count: 9
# Episode: 506 count: 9
# Episode: 507 count: 10
# Episode: 508 count: 8
# Episode: 509 count: 9
# Episode: 510 count: 8
# Episode: 511 count: 11
# Loss:  178.34308
# Episode: 512 count: 9
# Episode: 513 count: 10
# Episode: 514 count: 9
# Episode: 515 count: 9
# Episode: 516 count: 9
# Episode: 517 count: 10
# Episode: 518 count: 9
# Episode: 519 count: 9
# Episode: 520 count: 10
# Episode: 521 count: 10
# Loss:  241.05215
# Episode: 522 count: 10
# Episode: 523 count: 9
# Episode: 524 count: 9
# Episode: 525 count: 8
# Episode: 526 count: 9
# Episode: 527 count: 9
# Episode: 528 count: 10
# Episode: 529 count: 10
# Episode: 530 count: 10
# Episode: 531 count: 9
# Loss:  20.264927
# Episode: 532 count: 11
# Episode: 533 count: 8
# Episode: 534 count: 10
# Episode: 535 count: 10
# Episode: 536 count: 10
# Episode: 537 count: 10
# Episode: 538 count: 8
# Episode: 539 count: 10
# Episode: 540 count: 9
# Episode: 541 count: 10
# Loss:  107.52297
# Episode: 542 count: 10
# Episode: 543 count: 9
# Episode: 544 count: 10
# Episode: 545 count: 9
# Episode: 546 count: 10
# Episode: 547 count: 9
# Episode: 548 count: 9
# Episode: 549 count: 10
# Episode: 550 count: 9
# Episode: 551 count: 10
# Loss:  20.045403
# Episode: 552 count: 9
# Episode: 553 count: 9
# Episode: 554 count: 9
# Episode: 555 count: 9
# Episode: 556 count: 9
# Episode: 557 count: 9
# Episode: 558 count: 8
# Episode: 559 count: 10
# Episode: 560 count: 9
# Episode: 561 count: 10
# Loss:  292.98236
# Episode: 562 count: 85
# Episode: 563 count: 42
# Episode: 564 count: 57
# Episode: 565 count: 61
# Episode: 566 count: 61
# Episode: 567 count: 63
# Episode: 568 count: 59
# Episode: 569 count: 48
# Episode: 570 count: 58
# Episode: 571 count: 33
# Loss:  2.408154
# Episode: 572 count: 9
# Episode: 573 count: 12
# Episode: 574 count: 13
# Episode: 575 count: 10
# Episode: 576 count: 12
# Episode: 577 count: 11
# Episode: 578 count: 9
# Episode: 579 count: 13
# Episode: 580 count: 11
# Episode: 581 count: 11
# Loss:  5.3075123
# Episode: 582 count: 11
# Episode: 583 count: 9
# Episode: 584 count: 9
# Episode: 585 count: 10
# Episode: 586 count: 9
# Episode: 587 count: 9
# Episode: 588 count: 10
# Episode: 589 count: 10
# Episode: 590 count: 11
# Episode: 591 count: 10
# Loss:  12.966019
# Episode: 592 count: 9
# Episode: 593 count: 9
# Episode: 594 count: 9
# Episode: 595 count: 10
# Episode: 596 count: 10
# Episode: 597 count: 11
# Episode: 598 count: 9
# Episode: 599 count: 9
# Episode: 600 count: 9
# Episode: 601 count: 10
# Loss:  5.267867
# Episode: 602 count: 58
# Episode: 603 count: 51
# Episode: 604 count: 102
# Episode: 605 count: 28
# Episode: 606 count: 39
# Episode: 607 count: 68
# Episode: 608 count: 74
# Episode: 609 count: 30
# Episode: 610 count: 34
# Episode: 611 count: 32
# Loss:  7.5711336
# Episode: 612 count: 49
# Episode: 613 count: 108
# Episode: 614 count: 53
# Episode: 615 count: 39
# Episode: 616 count: 94
# Episode: 617 count: 63
# Episode: 618 count: 50
# Episode: 619 count: 51
# Episode: 620 count: 39
# Episode: 621 count: 67
# Loss:  6.9076524
# Episode: 622 count: 35
# Episode: 623 count: 31
# Episode: 624 count: 32
# Episode: 625 count: 34
# Episode: 626 count: 81
# Episode: 627 count: 38
# Episode: 628 count: 45
# Episode: 629 count: 52
# Episode: 630 count: 37
# Episode: 631 count: 36
# Loss:  299.66608
# Episode: 632 count: 73
# Episode: 633 count: 28
# Episode: 634 count: 30
# Episode: 635 count: 33
# Episode: 636 count: 58
# Episode: 637 count: 33
# Episode: 638 count: 52
# Episode: 639 count: 37
# Episode: 640 count: 46
# Episode: 641 count: 27
# Loss:  113.16185
# Episode: 642 count: 34
# Episode: 643 count: 39
# Episode: 644 count: 31
# Episode: 645 count: 25
# Episode: 646 count: 44
# Episode: 647 count: 24
# Episode: 648 count: 27
# Episode: 649 count: 54
# Episode: 650 count: 49
# Episode: 651 count: 54
# Loss:  11.980095
# Episode: 652 count: 26
# Episode: 653 count: 18
# Episode: 654 count: 17
# Episode: 655 count: 22
# Episode: 656 count: 29
# Episode: 657 count: 18
# Episode: 658 count: 24
# Episode: 659 count: 22
# Episode: 660 count: 23
# Episode: 661 count: 20
# Loss:  1.7448816
# Episode: 662 count: 16
# Episode: 663 count: 13
# Episode: 664 count: 16
# Episode: 665 count: 16
# Episode: 666 count: 17
# Episode: 667 count: 19
# Episode: 668 count: 12
# Episode: 669 count: 16
# Episode: 670 count: 14
# Episode: 671 count: 15
# Loss:  4.8556585
# Episode: 672 count: 18
# Episode: 673 count: 21
# Episode: 674 count: 17
# Episode: 675 count: 26
# Episode: 676 count: 16
# Episode: 677 count: 25
# Episode: 678 count: 23
# Episode: 679 count: 16
# Episode: 680 count: 23
# Episode: 681 count: 30
# Loss:  360.24896
# Episode: 682 count: 36
# Episode: 683 count: 34
# Episode: 684 count: 33
# Episode: 685 count: 51
# Episode: 686 count: 29
# Episode: 687 count: 34
# Episode: 688 count: 38
# Episode: 689 count: 52
# Episode: 690 count: 87
# Episode: 691 count: 54
# Loss:  13.130321
# Episode: 692 count: 38
# Episode: 693 count: 94
# Episode: 694 count: 55
# Episode: 695 count: 41
# Episode: 696 count: 29
# Episode: 697 count: 149
# Episode: 698 count: 32
# Episode: 699 count: 27
# Episode: 700 count: 47
# Episode: 701 count: 37
# Loss:  25.224682
# Episode: 702 count: 24
# Episode: 703 count: 33
# Episode: 704 count: 16
# Episode: 705 count: 18
# Episode: 706 count: 35
# Episode: 707 count: 27
# Episode: 708 count: 30
# Episode: 709 count: 38
# Episode: 710 count: 20
# Episode: 711 count: 78
# Loss:  6.680272
# Episode: 712 count: 74
# Episode: 713 count: 72
# Episode: 714 count: 78
# Episode: 715 count: 46
# Episode: 716 count: 38
# Episode: 717 count: 36
# Episode: 718 count: 54
# Episode: 719 count: 68
# Episode: 720 count: 78
# Episode: 721 count: 55
# Loss:  3.3950806
# Episode: 722 count: 28
# Episode: 723 count: 45
# Episode: 724 count: 31
# Episode: 725 count: 33
# Episode: 726 count: 34
# Episode: 727 count: 40
# Episode: 728 count: 30
# Episode: 729 count: 33
# Episode: 730 count: 31
# Episode: 731 count: 51
# Loss:  16.51898
# Episode: 732 count: 46
# Episode: 733 count: 30
# Episode: 734 count: 24
# Episode: 735 count: 31
# Episode: 736 count: 30
# Episode: 737 count: 40
# Episode: 738 count: 37
# Episode: 739 count: 27
# Episode: 740 count: 26
# Episode: 741 count: 56
# Loss:  228.29565
# Episode: 742 count: 53
# Episode: 743 count: 67
# Episode: 744 count: 61
# Episode: 745 count: 43
# Episode: 746 count: 82
# Episode: 747 count: 59
# Episode: 748 count: 45
# Episode: 749 count: 76
# Episode: 750 count: 35
# Episode: 751 count: 87
# Loss:  41.399067
# Episode: 752 count: 63
# Episode: 753 count: 93
# Episode: 754 count: 44
# Episode: 755 count: 60
# Episode: 756 count: 200
# Episode: 757 count: 200
# Episode: 758 count: 200
# Episode: 759 count: 85
# Episode: 760 count: 47
# Episode: 761 count: 200
# Loss:  4.718136
# Episode: 762 count: 61
# Episode: 763 count: 55
# Episode: 764 count: 83
# Episode: 765 count: 53
# Episode: 766 count: 37
# Episode: 767 count: 44
# Episode: 768 count: 65
# Episode: 769 count: 70
# Episode: 770 count: 74
# Episode: 771 count: 56
# Loss:  175.80124
# Episode: 772 count: 152
# Episode: 773 count: 49
# Episode: 774 count: 58
# Episode: 775 count: 43
# Episode: 776 count: 51
# Episode: 777 count: 80
# Episode: 778 count: 56
# Episode: 779 count: 40
# Episode: 780 count: 51
# Episode: 781 count: 54
# Loss:  7.86223
# Episode: 782 count: 200
# Episode: 783 count: 76
# Episode: 784 count: 70
# Episode: 785 count: 77
# Episode: 786 count: 160
# Episode: 787 count: 66
# Episode: 788 count: 200
# Episode: 789 count: 70
# Episode: 790 count: 200
# Episode: 791 count: 51
# Loss:  5.3496256
# Episode: 792 count: 49
# Episode: 793 count: 106
# Episode: 794 count: 200
# Episode: 795 count: 69
# Episode: 796 count: 55
# Episode: 797 count: 88
# Episode: 798 count: 105
# Episode: 799 count: 103
# Episode: 800 count: 200
# Episode: 801 count: 59
# Loss:  9.618688
# Episode: 802 count: 40
# Episode: 803 count: 70
# Episode: 804 count: 78
# Episode: 805 count: 46
# Episode: 806 count: 57
# Episode: 807 count: 42
# Episode: 808 count: 93
# Episode: 809 count: 66
# Episode: 810 count: 40
# Episode: 811 count: 142
# Loss:  5.8887906
# Episode: 812 count: 66
# Episode: 813 count: 200
# Episode: 814 count: 128
# Episode: 815 count: 86
# Episode: 816 count: 57
# Episode: 817 count: 52
# Episode: 818 count: 91
# Episode: 819 count: 80
# Episode: 820 count: 200
# Episode: 821 count: 66
# Loss:  3.6722023
# Episode: 822 count: 62
# Episode: 823 count: 58
# Episode: 824 count: 112
# Episode: 825 count: 62
# Episode: 826 count: 74
# Episode: 827 count: 52
# Episode: 828 count: 45
# Episode: 829 count: 75
# Episode: 830 count: 59
# Episode: 831 count: 200
# Loss:  3.1456645
# Episode: 832 count: 38
# Episode: 833 count: 40
# Episode: 834 count: 64
# Episode: 835 count: 38
# Episode: 836 count: 73
# Episode: 837 count: 40
# Episode: 838 count: 86
# Episode: 839 count: 77
# Episode: 840 count: 40
# Episode: 841 count: 55
# Loss:  3.5569465
# Episode: 842 count: 45
# Episode: 843 count: 46
# Episode: 844 count: 35
# Episode: 845 count: 154
# Episode: 846 count: 36
# Episode: 847 count: 47
# Episode: 848 count: 37
# Episode: 849 count: 200
# Episode: 850 count: 45
# Episode: 851 count: 37
# Loss:  2.742953
# Episode: 852 count: 200
# Episode: 853 count: 35
# Episode: 854 count: 37
# Episode: 855 count: 52
# Episode: 856 count: 49
# Episode: 857 count: 60
# Episode: 858 count: 44
# Episode: 859 count: 57
# Episode: 860 count: 42
# Episode: 861 count: 36
# Loss:  2.797624
# Episode: 862 count: 72
# Episode: 863 count: 53
# Episode: 864 count: 81
# Episode: 865 count: 53
# Episode: 866 count: 61
# Episode: 867 count: 81
# Episode: 868 count: 47
# Episode: 869 count: 33
# Episode: 870 count: 57
# Episode: 871 count: 77
# Loss:  2.9394321
# Episode: 872 count: 76
# Episode: 873 count: 47
# Episode: 874 count: 42
# Episode: 875 count: 66
# Episode: 876 count: 200
# Episode: 877 count: 86
# Episode: 878 count: 72
# Episode: 879 count: 72
# Episode: 880 count: 64
# Episode: 881 count: 93
# Loss:  1.9477336
# Episode: 882 count: 45
# Episode: 883 count: 51
# Episode: 884 count: 56
# Episode: 885 count: 74
# Episode: 886 count: 80
# Episode: 887 count: 106
# Episode: 888 count: 56
# Episode: 889 count: 49
# Episode: 890 count: 75
# Episode: 891 count: 57
# Loss:  1.1275017
# Episode: 892 count: 48
# Episode: 893 count: 86
# Episode: 894 count: 54
# Episode: 895 count: 59
# Episode: 896 count: 59
# Episode: 897 count: 200
# Episode: 898 count: 37
# Episode: 899 count: 73
# Episode: 900 count: 46
# Episode: 901 count: 58
# Loss:  2.6219246
# Episode: 902 count: 43
# Episode: 903 count: 36
# Episode: 904 count: 45
# Episode: 905 count: 200
# Episode: 906 count: 43
# Episode: 907 count: 55
# Episode: 908 count: 45
# Episode: 909 count: 49
# Episode: 910 count: 84
# Episode: 911 count: 54
# Loss:  3.0636044
# Episode: 912 count: 200
# Episode: 913 count: 41
# Episode: 914 count: 44
# Episode: 915 count: 37
# Episode: 916 count: 33
# Episode: 917 count: 156
# Episode: 918 count: 36
# Episode: 919 count: 59
# Episode: 920 count: 59
# Episode: 921 count: 37
# Loss:  2.2085843
# Episode: 922 count: 31
# Episode: 923 count: 41
# Episode: 924 count: 31
# Episode: 925 count: 34
# Episode: 926 count: 31
# Episode: 927 count: 34
# Episode: 928 count: 47
# Episode: 929 count: 200
# Episode: 930 count: 37
# Episode: 931 count: 83
# Loss:  336.2447
# Episode: 932 count: 43
# Episode: 933 count: 35
# Episode: 934 count: 37
# Episode: 935 count: 67
# Episode: 936 count: 35
# Episode: 937 count: 169
# Episode: 938 count: 34
# Episode: 939 count: 143
# Episode: 940 count: 35
# Episode: 941 count: 37
# Loss:  7.7034674
# Episode: 942 count: 50
# Episode: 943 count: 63
# Episode: 944 count: 66
# Episode: 945 count: 55
# Episode: 946 count: 43
# Episode: 947 count: 87
# Episode: 948 count: 39
# Episode: 949 count: 43
# Episode: 950 count: 43
# Episode: 951 count: 43
# Loss:  6.609009
# Episode: 952 count: 78
# Episode: 953 count: 72
# Episode: 954 count: 65
# Episode: 955 count: 80
# Episode: 956 count: 65
# Episode: 957 count: 63
# Episode: 958 count: 62
# Episode: 959 count: 81
# Episode: 960 count: 62
# Episode: 961 count: 78
# Loss:  6.615658
# Episode: 962 count: 61
# Episode: 963 count: 64
# Episode: 964 count: 64
# Episode: 965 count: 121
# Episode: 966 count: 75
# Episode: 967 count: 200
# Episode: 968 count: 50
# Episode: 969 count: 58
# Episode: 970 count: 60
# Episode: 971 count: 74
# Loss:  7.27521
# Episode: 972 count: 70
# Episode: 973 count: 45
# Episode: 974 count: 40
# Episode: 975 count: 169
# Episode: 976 count: 41
# Episode: 977 count: 44
# Episode: 978 count: 144
# Episode: 979 count: 166
# Episode: 980 count: 77
# Episode: 981 count: 53
# Loss:  32.303925
# Episode: 982 count: 37
# Episode: 983 count: 42
# Episode: 984 count: 43
# Episode: 985 count: 45
# Episode: 986 count: 37
# Episode: 987 count: 37
# Episode: 988 count: 41
# Episode: 989 count: 41
# Episode: 990 count: 34
# Episode: 991 count: 47
# Loss:  11.574335
# Episode: 992 count: 44
# Episode: 993 count: 51
# Episode: 994 count: 64
# Episode: 995 count: 35
# Episode: 996 count: 43
# Episode: 997 count: 38
# Episode: 998 count: 61
# Episode: 999 count: 43
# Episode: 1000 count: 35
# Episode: 1001 count: 64
# Loss:  2.7403286
# Episode: 1002 count: 62
# Episode: 1003 count: 66
# Episode: 1004 count: 52
# Episode: 1005 count: 54
# Episode: 1006 count: 51
# Episode: 1007 count: 127
# Episode: 1008 count: 66
# Episode: 1009 count: 57
# Episode: 1010 count: 58
# Episode: 1011 count: 95
# Loss:  1.2560227
# Episode: 1012 count: 200
# Episode: 1013 count: 200
# Episode: 1014 count: 200
# Episode: 1015 count: 200
# Episode: 1016 count: 140
# Episode: 1017 count: 90
# Episode: 1018 count: 200
# Episode: 1019 count: 200
# Episode: 1020 count: 200
# Episode: 1021 count: 125
# Loss:  11.674494
# Episode: 1022 count: 89
# Episode: 1023 count: 71
# Episode: 1024 count: 89
# Episode: 1025 count: 62
# Episode: 1026 count: 86
# Episode: 1027 count: 67
# Episode: 1028 count: 81
# Episode: 1029 count: 200
# Episode: 1030 count: 82
# Episode: 1031 count: 200
# Loss:  9.236241
# Episode: 1032 count: 83
# Episode: 1033 count: 67
# Episode: 1034 count: 65
# Episode: 1035 count: 92
# Episode: 1036 count: 68
# Episode: 1037 count: 58
# Episode: 1038 count: 200
# Episode: 1039 count: 77
# Episode: 1040 count: 72
# Episode: 1041 count: 78
# Loss:  408.12946
# Episode: 1042 count: 118
# Episode: 1043 count: 119
# Episode: 1044 count: 147
# Episode: 1045 count: 109
# Episode: 1046 count: 134
# Episode: 1047 count: 192
# Episode: 1048 count: 111
# Episode: 1049 count: 114
# Episode: 1050 count: 119
# Episode: 1051 count: 163
# Loss:  5.383857
# Episode: 1052 count: 200
# Episode: 1053 count: 200
# Episode: 1054 count: 178
# Episode: 1055 count: 200
# Episode: 1056 count: 146
# Episode: 1057 count: 194
# Episode: 1058 count: 167
# Episode: 1059 count: 200
# Episode: 1060 count: 180
# Episode: 1061 count: 200
# Loss:  10.873792
# Episode: 1062 count: 200
# Episode: 1063 count: 200
# Episode: 1064 count: 200
# Episode: 1065 count: 200
# Episode: 1066 count: 200
# Episode: 1067 count: 200
# Episode: 1068 count: 200
# Episode: 1069 count: 200
# Episode: 1070 count: 200
# Episode: 1071 count: 200
# Loss:  397.42828
# Episode: 1072 count: 200
# Episode: 1073 count: 200
# Episode: 1074 count: 200
# Episode: 1075 count: 200
# Episode: 1076 count: 200
# Episode: 1077 count: 200
# Episode: 1078 count: 190
# Episode: 1079 count: 200
# Episode: 1080 count: 200
# Episode: 1081 count: 200
# Loss:  3.827335
# Episode: 1082 count: 200
# Episode: 1083 count: 150
# Episode: 1084 count: 138
# Episode: 1085 count: 172
# Episode: 1086 count: 160
# Episode: 1087 count: 200
# Episode: 1088 count: 153
# Episode: 1089 count: 141
# Episode: 1090 count: 200
# Episode: 1091 count: 143
# Loss:  1.4511726
# Episode: 1092 count: 125
# Episode: 1093 count: 131
# Episode: 1094 count: 126
# Episode: 1095 count: 126
# Episode: 1096 count: 140
# Episode: 1097 count: 144
# Episode: 1098 count: 120
# Episode: 1099 count: 142
# Episode: 1100 count: 124
# Episode: 1101 count: 112
# Loss:  1.5999377
# Episode: 1102 count: 115
# Episode: 1103 count: 115
# Episode: 1104 count: 105
# Episode: 1105 count: 111
# Episode: 1106 count: 95
# Episode: 1107 count: 105
# Episode: 1108 count: 111
# Episode: 1109 count: 117
# Episode: 1110 count: 134
# Episode: 1111 count: 100
# Loss:  1.8028562
# Episode: 1112 count: 120
# Episode: 1113 count: 117
# Episode: 1114 count: 106
# Episode: 1115 count: 118
# Episode: 1116 count: 124
# Episode: 1117 count: 110
# Episode: 1118 count: 105
# Episode: 1119 count: 101
# Episode: 1120 count: 119
# Episode: 1121 count: 94
# Loss:  1.7375829
# Episode: 1122 count: 110
# Episode: 1123 count: 127
# Episode: 1124 count: 120
# Episode: 1125 count: 123
# Episode: 1126 count: 113
# Episode: 1127 count: 126
# Episode: 1128 count: 102
# Episode: 1129 count: 118
# Episode: 1130 count: 106
# Episode: 1131 count: 100
# Loss:  0.5192112
# Episode: 1132 count: 118
# Episode: 1133 count: 118
# Episode: 1134 count: 106
# Episode: 1135 count: 122
# Episode: 1136 count: 125
# Episode: 1137 count: 126
# Episode: 1138 count: 132
# Episode: 1139 count: 117
# Episode: 1140 count: 121
# Episode: 1141 count: 125
# Loss:  391.74435
# Episode: 1142 count: 121
# Episode: 1143 count: 126
# Episode: 1144 count: 152
# Episode: 1145 count: 131
# Episode: 1146 count: 127
# Episode: 1147 count: 135
# Episode: 1148 count: 154
# Episode: 1149 count: 141
# Episode: 1150 count: 119
# Episode: 1151 count: 121
# Loss:  2.7774987
# Episode: 1152 count: 60
# Episode: 1153 count: 69
# Episode: 1154 count: 83
# Episode: 1155 count: 66
# Episode: 1156 count: 69
# Episode: 1157 count: 60
# Episode: 1158 count: 61
# Episode: 1159 count: 55
# Episode: 1160 count: 83
# Episode: 1161 count: 72
# Loss:  4.3103704
# Episode: 1162 count: 65
# Episode: 1163 count: 58
# Episode: 1164 count: 77
# Episode: 1165 count: 56
# Episode: 1166 count: 77
# Episode: 1167 count: 69
# Episode: 1168 count: 65
# Episode: 1169 count: 71
# Episode: 1170 count: 49
# Episode: 1171 count: 55
# Loss:  6.575773
# Episode: 1172 count: 84
# Episode: 1173 count: 114
# Episode: 1174 count: 61
# Episode: 1175 count: 66
# Episode: 1176 count: 76
# Episode: 1177 count: 78
# Episode: 1178 count: 67
# Episode: 1179 count: 86
# Episode: 1180 count: 66
# Episode: 1181 count: 70
# Loss:  4.8728867
# Episode: 1182 count: 165
# Episode: 1183 count: 152
# Episode: 1184 count: 167
# Episode: 1185 count: 200
# Episode: 1186 count: 147
# Episode: 1187 count: 200
# Episode: 1188 count: 180
# Episode: 1189 count: 200
# Episode: 1190 count: 200
# Episode: 1191 count: 161
# Loss:  3.4107704
# Episode: 1192 count: 200
# Episode: 1193 count: 200
# Episode: 1194 count: 200
# Episode: 1195 count: 200
# Episode: 1196 count: 200
# Episode: 1197 count: 200
# Episode: 1198 count: 200
# Episode: 1199 count: 200

# %% [markdown]
# ## <a name="play"></a> 3. Test the trained agent ( 50 points )
#
# Now, we test your agent and calculate an average reward of 20 episodes.
# - 0 <= average reward < 50 : you can get 0 points
# - 50 <= average reward < 100 : you can get 10 points
# - 100 <= average reward < 190 : you can get 35 points
# - 190 <= average reward <= 200 : you can get 50 points

# %%
config = tf.ConfigProto()
# If you use a GPU, uncomment
#os.environ["CUDA_VISIBLE_DEVICES"] = '0'
config.log_device_placement = False
config.gpu_options.allow_growth = True
tf.reset_default_graph()
with tf.Session(config=config) as sess:
    args = parser.parse_args() # You set the option of test phase
    myAgent = Agent(args, sess) # It depends on your class implementation
    myAgent.load()
    rewards = []
    for i in range(20):
        r = myAgent.play() # play() returns the reward cumulated in one episode
        rewards.append(r)
    mean = np.mean(rewards)
    print(rewards)
    print(mean)
# Out:
# INFO:tensorflow:Restoring parameters from cartpole/trained_agent
# [2019-12-08 16:38:19,152] Restoring parameters from cartpole/trained_agent
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# Total reward: 200.0
# [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0]
# 200.0
